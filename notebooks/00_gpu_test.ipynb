# %%
import torch
import cv2
import transformers
import matplotlib
import sklearn

print(f"PyTorch version: {torch.__version__}")
print(f"OpenCV: {cv2.__version__}")
print(f"Transformers: {transformers.__version__}")

# Use CPU for now — works perfectly fine
device = torch.device('cpu')
print(f"\nDevice: {device}")

# Quick test — create a tensor and do math on it
x = torch.randn(3, 3)
y = torch.randn(3, 3)
z = x @ y
print(f"Tensor test passed: {z.shape}")

print("\n✅ Everything working! Ready to build the model.")
# Out:
# PyTorch version: 2.12.1+cpu
# OpenCV: 5.0.0
# Transformers: 5.12.1
#
# Device: cpu
# Tensor test passed: torch.Size([3, 3])
#
# ✅ Everything working! Ready to build the model.
